# %%
import os
from google.colab import drive
drive.mount('/content/drive/')
cd /content/drive/MyDrive/ColabNotebooks/Github
# !git clone https://haenalee0721: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@github.com/haenalee0721/ImageProcessing.git
cd ImageProcessing/
# Out:
# Mounted at /content/drive/
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-25e3b16c027c> in <cell line: 4>()
#       2 from google.colab import drive
#       3 drive.mount('/content/drive/')
# ----> 4 cd /content/drive/MyDrive/ColabNotebooks/Github
#       5 get_ipython().system('git clone https://haenalee0721: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@github.com/haenalee0721/ImageProcessing.git')
#
# NameError: name 'cd' is not defined

# %%
# !git config --global user.email 'haenalee0721@gmail.com'
# !git config --global user.name 'haenalee0721'
# !git add --all
# !git commit -m 'test'
# !git push
# Out:
# On branch master
#
# Initial commit
#
# nothing to commit (create/copy files and use "git add" to track)
# error: src refspec refs/heads/master does not match any
# error: failed to push some refs to 'https://haenalee0721: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@github.com/haenalee0721/ImageProcessing.git'

# %%
import cv2

# %%
raw =cv2.imread('pepper.raw', cv2.IMREAD_COLOR)
bmp=cv2.imread('baboon.bmp', cv2.IMREAD_COLOR)
jpeg=cv2.imread('goldhill.jpg', cv2.IMREAD_COLOR)

cv2.imshow('raw',raw)
cv2.imshow('bmp',bmp)
cv2.imshow('jpeg',jpeg)
cv2.waitKey(0)
cv2.destroyAllWindows()
cv2.waitKey(1)
# Out:
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# Input In [6], in <cell line: 5>()
#       2 bmp=cv2.imread('baboon.bmp', cv2.IMREAD_COLOR)
#       3 jpeg=cv2.imread('goldhill.jpg', cv2.IMREAD_COLOR)
# ----> 5 cv2.imshow('raw',raw)
#       6 cv2.imshow('bmp',bmp)
#       7 cv2.imshow('jpeg',jpeg)
#
# error: OpenCV(4.7.0) D:\a\opencv-python\opencv-python\opencv\modules\highgui\src\window.cpp:971: error: (-215:Assertion failed) size.width>0 && size.height>0 in function 'cv::imshow'

# %%
import cv2
import numpy as np
